# %% [markdown]
# # Quantum Multiplier
#
# Initalization and imports:

# %%
# Initializing and importing
from qiskit import IBMQ, Aer
from qiskit_ibm_provider import IBMProvider
IBMQ.save_account(open("ibm_token.txt","r").read())
IBMQ.load_account()
IBMQ.providers()
provider = IBMQ.get_provider("ibm-q")

import building_blocks
import runtime
# Out:
# /tmp/ipykernel_250/2236319338.py:4: DeprecationWarning: The package qiskit.providers.ibmq is being deprecated. Please see https://ibm.biz/provider_migration_guide to get instructions on how to migrate to qiskit-ibm-provider (https://github.com/Qiskit/qiskit-ibm-provider) and qiskit-ibm-runtime (https://github.com/Qiskit/qiskit-ibm-runtime).
#   IBMQ.save_account(open("ibm_token.txt","r").read())
# /tmp/ipykernel_250/2236319338.py:4: DeprecationWarning: The qiskit.IBMQ entrypoint and the qiskit-ibmq-provider package (accessible from 'qiskit.providers.ibmq`) are deprecated and will be removed in a future release. Instead you should use the qiskit-ibm-provider package which is accessible from 'qiskit_ibm_provider'. You can install it with 'pip install qiskit_ibm_provider'. Just replace 'qiskit.IBMQ' with 'qiskit_ibm_provider.IBMProvider'
#   IBMQ.save_account(open("ibm_token.txt","r").read())
# configrc.store_credentials:WARNING:2023-05-18 23:25:15,372: Credentials already present. Set overwrite=True to overwrite.

# %%
# Settings
number_1 = 5
number_2 = 5
shots = 1
backend = provider.get_backend('ibmq_qasm_simulator')

# %% [markdown]
# **For running the full program, run this cell:**
#
# NOTE: The high-level circuit diagram will be shown in a compressed one-line fashion. For viewing it in its real dimensions press right-click on it, and then press "Open image in new tab" (first option).

# %%
# Run Program
runtime.RunProgram(number_1 = number_1, number_2 = number_2, backend = backend, shots = shots)
# Out:
# The chosen backend is ibmq_qasm_simulator
#
# **The system synthesizes the appropriate quantum circuit..**
# **Synthesis done.**
#
# Transpiling the circuit..
# Transpilation done.
#
# Sending the job to the backend..
# Job Status: job has successfully run
# Execution time:  0.0186 seconds
#
# number_1 * number_2 = 5 * 5 = 25
#
# The transpiled circuit depth is: 547
#
# The transpiled circuit's gate count is: OrderedDict([('cp', 330), ('ccx', 210), ('h', 12), ('measure', 6), ('x', 4), ('barrier', 3), ('swap', 3)])
#
# The results of running the circuit 1 times:
# The high-level circuit:

# %% [markdown]
# **For getting a simple answer - run this cell:**

# %%
# Multiplication answer only
runtime.multiplier(number_1 = number_1, number_2 = number_2, backend = backend, shots = shots)['product']
